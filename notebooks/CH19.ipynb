# %% [markdown]
# # 19장. GAN(Generative Adversarial Networks) 모델

# %% [markdown]
# ## Anaconda에서 개발환경 만들기
# ```bash
# conda env create -f env_CH19.yml
# conda activate gan
# ```

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %% [markdown]
# ## 19.1 min-max 최적화 문제 소개

# %%
import pickle as pkl
import numpy as np
import tensorflow as tf
import matplotlib.pylab as plt
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets('MNIST_data')
# Out:
# WARNING:tensorflow:From <ipython-input-2-6ab9ddc08436>:6: read_data_sets (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# WARNING:tensorflow:From C:\Users\HanByul\Anaconda3\envs\mnist-classification\lib\site-packages\tensorflow\contrib\learn\python\learn\datasets\mnist.py:260: maybe_download (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please write your own downloading logic.
# WARNING:tensorflow:From C:\Users\HanByul\Anaconda3\envs\mnist-classification\lib\site-packages\tensorflow\contrib\learn\python\learn\datasets\base.py:252: _internal_retry.<locals>.wrap.<locals>.wrapped_fn (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use urllib or similar directly.
# Successfully downloaded train-images-idx3-ubyte.gz 9912422 bytes.
# WARNING:tensorflow:From C:\Users\HanByul\Anaconda3\envs\mnist-classification\lib\site-packages\tensorflow\contrib\learn\python\learn\datasets\mnist.py:262: extract_images (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting MNIST_data\train-images-idx3-ubyte.gz
# Successfully downloaded train-labels-idx1-ubyte.gz 28881 bytes.
# WARNING:tensorflow:From C:\Users\HanByul\Anaconda3\envs\mnist-classification\lib\site-packages\tensorflow\contrib\learn\python\learn\datasets\mnist.py:267: extract_labels (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting MNIST_data\train-labels-idx1-ubyte.gz
# Successfully downloaded t10k-images-idx3-ubyte.gz 1648877 bytes.
# Extracting MNIST_data\t10k-images-idx3-ubyte.gz
# Successfully downloaded t10k-labels-idx1-ubyte.gz 4542 bytes.
# Extracting MNIST_data\t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From C:\Users\HanByul\Anaconda3\envs\mnist-classification\lib\site-packages\tensorflow\contrib\learn\python\learn\datasets\mnist.py:290: DataSet.__init__ (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.

# %%
def model_inputs(real_dim, z_dim):
    inputs_real = tf.placeholder(tf.float32, (None, real_dim), name='input_real') 
    inputs_z = tf.placeholder(tf.float32, (None, z_dim), name='input_z')
    return inputs_real, inputs_z

# %% [markdown]
# ## 19.2 Generator(생성기)

# %%
def generator(z, out_dim, n_units=128, reuse=False, alpha=0.01):
    with tf.variable_scope('generator', reuse=reuse):
        # Hidden layer
        h1 = tf.layers.dense(z, n_units, activation=None)
        # Leaky ReLU
        h1 = tf.maximum(alpha * h1, h1)
        
        # Logits and tanh output
        logits = tf.layers.dense(h1, out_dim, activation=None)
        out = tf.tanh(logits)
        
        return out

# %% [markdown]
# ## 19.3 Discriminator(판별기)

# %%
def discriminator(x, n_units=128, reuse=False, alpha=0.01):
    with tf.variable_scope('discriminator', reuse=reuse):
        # Hidden layer
        h1 = tf.layers.dense(x, n_units, activation=None)
        # Leaky ReLU
        h1 = tf.maximum(alpha * h1, h1)
        
        logits = tf.layers.dense(h1, 1, activation=None)
        out = tf.sigmoid(logits)
        
        return out, logits

# %% [markdown]
# ## 19.4 GAN 네트워크 만들기
# ### 19.4.1 Hyperparameters

# %%
# Size of input image to discriminator
input_size = 784
# Size of latent vector to generator
z_size = 100
# Sizes of hidden layers in generator and discriminator
g_hidden_size = 128
d_hidden_size = 128
# Leak factor for leaky ReLU
alpha = 0.01
# Smoothing 
smooth = 0.1

# %%
tf.reset_default_graph()
# Create our input placeholders
input_real, input_z = model_inputs(input_size, z_size)

# Build the model
g_model = generator(input_z, input_size, n_units=g_hidden_size, alpha=alpha)
# g_model is the generator output

d_model_real, d_logits_real = discriminator(input_real, n_units=d_hidden_size, alpha=alpha)
d_model_fake, d_logits_fake = discriminator(g_model, reuse=True, n_units=d_hidden_size, alpha=alpha)

# %% [markdown]
# ## 19.5 손실함수

# %%
# Calculate losses
d_loss_real = tf.reduce_mean(
                  tf.nn.sigmoid_cross_entropy_with_logits(logits=d_logits_real, 
                                                          labels=tf.ones_like(d_logits_real) * (1 - smooth)))
d_loss_fake = tf.reduce_mean(
                  tf.nn.sigmoid_cross_entropy_with_logits(logits=d_logits_fake, 
                                                          labels=tf.zeros_like(d_logits_real)))
d_loss = d_loss_real + d_loss_fake

g_loss = tf.reduce_mean(
             tf.nn.sigmoid_cross_entropy_with_logits(logits=d_logits_fake,
                                                     labels=tf.ones_like(d_logits_fake)))

# %% [markdown]
# ## 19.6 Training(학습)

# %%
# Optimizers
learning_rate = 0.002

# Get the trainable_variables, split into G and D parts
t_vars = tf.trainable_variables()
g_vars = [var for var in t_vars if var.name.startswith('generator')]
d_vars = [var for var in t_vars if var.name.startswith('discriminator')]

d_train_opt = tf.train.AdamOptimizer(learning_rate).minimize(d_loss, var_list=d_vars)
g_train_opt = tf.train.AdamOptimizer(learning_rate).minimize(g_loss, var_list=g_vars)

# %% [markdown]
# ### 19.6.1 Training(학습)의 세부 조건 설정

# %%
batch_size = 100
epochs = 100
samples = []
losses = []
# Only save generator variables
saver = tf.train.Saver(var_list=g_vars)
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    for e in range(epochs):
        for ii in range(mnist.train.num_examples//batch_size):
            batch = mnist.train.next_batch(batch_size)
            
            # Get images, reshape and rescale to pass to D
            batch_images = batch[0].reshape((batch_size, 784))
            batch_images = batch_images*2 - 1
            
            # Sample random noise for G
            batch_z = np.random.uniform(-1, 1, size=(batch_size, z_size))
            
            # Run optimizers
            _ = sess.run(d_train_opt, feed_dict={input_real: batch_images, input_z: batch_z})
            _ = sess.run(g_train_opt, feed_dict={input_z: batch_z})
        
        # At the end of each epoch, get the losses and print them out
        train_loss_d = sess.run(d_loss, {input_z: batch_z, input_real: batch_images})
        train_loss_g = g_loss.eval({input_z: batch_z})
            
        print("Epoch {}/{}...".format(e+1, epochs),
              "Discriminator Loss: {:.4f}...".format(train_loss_d),
              "Generator Loss: {:.4f}".format(train_loss_g))    
        # Save losses to view after training
        losses.append((train_loss_d, train_loss_g))
        
        # Sample from generator as we're training for viewing afterwards
        sample_z = np.random.uniform(-1, 1, size=(16, z_size))
        gen_samples = sess.run(
                       generator(input_z, input_size, n_units=g_hidden_size, reuse=True, alpha=alpha),
                       feed_dict={input_z: sample_z})
        samples.append(gen_samples)
        saver.save(sess, './checkpoints/generator.ckpt')

# Save training generator samples
with open('train_samples.pkl', 'wb') as f:
    pkl.dump(samples, f)
# Out:
# Epoch 1/100... Discriminator Loss: 0.3601... Generator Loss: 3.6945
# Epoch 2/100... Discriminator Loss: 0.4009... Generator Loss: 3.6132
# Epoch 3/100... Discriminator Loss: 0.4770... Generator Loss: 3.3933
# Epoch 4/100... Discriminator Loss: 0.4104... Generator Loss: 3.1386
# Epoch 5/100... Discriminator Loss: 0.6352... Generator Loss: 5.3913
# Epoch 6/100... Discriminator Loss: 1.3767... Generator Loss: 7.8183
# Epoch 7/100... Discriminator Loss: 1.1964... Generator Loss: 1.7764
# Epoch 8/100... Discriminator Loss: 1.0774... Generator Loss: 1.5261
# Epoch 9/100... Discriminator Loss: 0.8081... Generator Loss: 2.6888
# Epoch 10/100... Discriminator Loss: 0.9834... Generator Loss: 1.5454
# Epoch 11/100... Discriminator Loss: 1.0012... Generator Loss: 1.4494
# Epoch 12/100... Discriminator Loss: 0.9902... Generator Loss: 1.6911
# Epoch 13/100... Discriminator Loss: 0.9214... Generator Loss: 2.1248
# Epoch 14/100... Discriminator Loss: 0.9810... Generator Loss: 1.5184
# Epoch 15/100... Discriminator Loss: 1.3587... Generator Loss: 2.2571
# Epoch 16/100... Discriminator Loss: 1.0246... Generator Loss: 1.5850
# Epoch 17/100... Discriminator Loss: 0.6476... Generator Loss: 3.5345
# Epoch 18/100... Discriminator Loss: 1.3896... Generator Loss: 0.9906
# Epoch 19/100... Discriminator Loss: 1.0035... Generator Loss: 2.1664
# Epoch 20/100... Discriminator Loss: 0.9477... Generator Loss: 2.7619
# Epoch 21/100... Discriminator Loss: 0.8433... Generator Loss: 2.1278
# Epoch 22/100... Discriminator Loss: 0.8342... Generator Loss: 3.0205
# Epoch 23/100... Discriminator Loss: 0.9874... Generator Loss: 1.6780
# Epoch 24/100... Discriminator Loss: 0.8199... Generator Loss: 2.0369
# Epoch 25/100... Discriminator Loss: 1.0288... Generator Loss: 1.8448
# Epoch 26/100... Discriminator Loss: 1.3221... Generator Loss: 1.4550
# Epoch 27/100... Discriminator Loss: 0.7675... Generator Loss: 2.2205
# Epoch 28/100... Discriminator Loss: 0.7070... Generator Loss: 2.8217
# Epoch 29/100... Discriminator Loss: 1.2196... Generator Loss: 2.7396
# Epoch 30/100... Discriminator Loss: 1.0398... Generator Loss: 1.6590
# Epoch 31/100... Discriminator Loss: 0.8543... Generator Loss: 1.8633
# Epoch 32/100... Discriminator Loss: 0.8294... Generator Loss: 2.4846
# Epoch 33/100... Discriminator Loss: 0.8919... Generator Loss: 1.9086
# Epoch 34/100... Discriminator Loss: 1.1667... Generator Loss: 2.0783
# Epoch 35/100... Discriminator Loss: 0.8116... Generator Loss: 1.8928
# Epoch 36/100... Discriminator Loss: 0.7475... Generator Loss: 2.6210
# Epoch 37/100... Discriminator Loss: 1.0113... Generator Loss: 1.8923
# Epoch 38/100... Discriminator Loss: 0.8241... Generator Loss: 2.3224
# Epoch 39/100... Discriminator Loss: 0.8316... Generator Loss: 2.3643
# Epoch 40/100... Discriminator Loss: 0.9317... Generator Loss: 2.0862
# Epoch 41/100... Discriminator Loss: 0.7886... Generator Loss: 1.9767
# Epoch 42/100... Discriminator Loss: 0.7579... Generator Loss: 2.3031
# Epoch 43/100... Discriminator Loss: 1.0409... Generator Loss: 1.5616
# Epoch 44/100... Discriminator Loss: 1.1563... Generator Loss: 1.9131
# Epoch 45/100... Discriminator Loss: 0.9805... Generator Loss: 2.1374
# Epoch 46/100... Discriminator Loss: 1.1119... Generator Loss: 2.0139
# Epoch 47/100... Discriminator Loss: 0.9011... Generator Loss: 1.7957
# Epoch 48/100... Discriminator Loss: 0.7715... Generator Loss: 2.8172
# Epoch 49/100... Discriminator Loss: 0.8678... Generator Loss: 2.1547
# Epoch 50/100... Discriminator Loss: 0.9057... Generator Loss: 2.3319
# Epoch 51/100... Discriminator Loss: 1.1446... Generator Loss: 1.6432
# Epoch 52/100... Discriminator Loss: 0.9210... Generator Loss: 2.0768
# Epoch 53/100... Discriminator Loss: 0.9477... Generator Loss: 1.7253
# Epoch 54/100... Discriminator Loss: 0.8306... Generator Loss: 2.2868
# Epoch 55/100... Discriminator Loss: 0.9248... Generator Loss: 1.7910
# Epoch 56/100... Discriminator Loss: 1.3607... Generator Loss: 1.1929
# Epoch 57/100... Discriminator Loss: 0.9273... Generator Loss: 2.0428
# Epoch 58/100... Discriminator Loss: 0.7941... Generator Loss: 2.1383
# Epoch 59/100... Discriminator Loss: 0.8653... Generator Loss: 2.0804
# Epoch 60/100... Discriminator Loss: 0.9805... Generator Loss: 1.9605
# Epoch 61/100... Discriminator Loss: 0.8491... Generator Loss: 1.9102
# Epoch 62/100... Discriminator Loss: 0.9824... Generator Loss: 1.8171
# Epoch 63/100... Discriminator Loss: 0.9083... Generator Loss: 1.9495
# Epoch 64/100... Discriminator Loss: 1.0484... Generator Loss: 1.9630
# Epoch 65/100... Discriminator Loss: 1.0352... Generator Loss: 1.6858
# Epoch 66/100... Discriminator Loss: 0.9641... Generator Loss: 1.8317
# Epoch 67/100... Discriminator Loss: 1.1685... Generator Loss: 1.9316
# Epoch 68/100... Discriminator Loss: 1.0177... Generator Loss: 1.6659
# Epoch 69/100... Discriminator Loss: 0.8574... Generator Loss: 2.2413
# Epoch 70/100... Discriminator Loss: 0.9991... Generator Loss: 2.0085
# Epoch 71/100... Discriminator Loss: 0.8941... Generator Loss: 2.5300
# Epoch 72/100... Discriminator Loss: 1.0068... Generator Loss: 1.6678
# Epoch 73/100... Discriminator Loss: 1.0137... Generator Loss: 2.0222
# Epoch 74/100... Discriminator Loss: 1.0402... Generator Loss: 2.4594
# Epoch 75/100... Discriminator Loss: 0.9816... Generator Loss: 1.7866
# Epoch 76/100... Discriminator Loss: 1.0527... Generator Loss: 1.5097
# Epoch 77/100... Discriminator Loss: 1.0209... Generator Loss: 1.6167
# Epoch 78/100... Discriminator Loss: 1.2656... Generator Loss: 2.2495
# Epoch 79/100... Discriminator Loss: 1.0193... Generator Loss: 2.1616
# Epoch 80/100... Discriminator Loss: 0.9975... Generator Loss: 1.6986
# Epoch 81/100... Discriminator Loss: 1.0624... Generator Loss: 1.6685
# Epoch 82/100... Discriminator Loss: 1.1686... Generator Loss: 1.4360
# Epoch 83/100... Discriminator Loss: 0.9768... Generator Loss: 1.5308
# Epoch 84/100... Discriminator Loss: 0.9863... Generator Loss: 1.8866
# Epoch 85/100... Discriminator Loss: 1.0591... Generator Loss: 1.7101
# Epoch 86/100... Discriminator Loss: 1.0378... Generator Loss: 1.9088
# Epoch 87/100... Discriminator Loss: 0.8136... Generator Loss: 2.0668
# Epoch 88/100... Discriminator Loss: 0.8730... Generator Loss: 1.7181
# Epoch 89/100... Discriminator Loss: 1.0304... Generator Loss: 1.7487
# Epoch 90/100... Discriminator Loss: 1.0802... Generator Loss: 1.7977
# Epoch 91/100... Discriminator Loss: 0.8752... Generator Loss: 2.0267
# Epoch 92/100... Discriminator Loss: 0.9182... Generator Loss: 2.0631
# Epoch 93/100... Discriminator Loss: 0.9638... Generator Loss: 1.7337
# Epoch 94/100... Discriminator Loss: 0.9899... Generator Loss: 1.8509
# Epoch 95/100... Discriminator Loss: 1.0257... Generator Loss: 1.9597
# Epoch 96/100... Discriminator Loss: 1.0148... Generator Loss: 1.4897
# Epoch 97/100... Discriminator Loss: 0.8822... Generator Loss: 2.0691
# Epoch 98/100... Discriminator Loss: 0.9751... Generator Loss: 1.7461
# Epoch 99/100... Discriminator Loss: 0.9841... Generator Loss: 1.6457
# Epoch 100/100... Discriminator Loss: 1.0164... Generator Loss: 1.8907

# %% [markdown]
# ### 19.6.2 Training loss(학습 손실)

# %%
fig, ax = plt.subplots()
losses = np.array(losses)
plt.plot(losses.T[0], label='Discriminator')
plt.plot(losses.T[1], label='Generator')
plt.title("Training Losses")
plt.legend()

# %% [markdown]
# ### 19.6.3 생성기로 만든 샘플 영상

# %%
def view_samples(epoch, samples):
    fig, axes = plt.subplots(figsize=(7,7), nrows=4, ncols=4, sharey=True, sharex=True)
    for ax, img in zip(axes.flatten(), samples[epoch]):
        ax.xaxis.set_visible(False)
        ax.yaxis.set_visible(False)
        im = ax.imshow(img.reshape((28,28)), cmap='Greys_r')
    
    return fig, axes

# %%
# Load samples from generator taken while training
with open('train_samples.pkl', 'rb') as f:
    samples = pkl.load(f)

# %%
_ = view_samples(-1, samples)

# %%
rows, cols = 10, 6
fig, axes = plt.subplots(figsize=(7,12), nrows=rows, ncols=cols, sharex=True, sharey=True)

for sample, ax_row in zip(samples[::int(len(samples)/rows)], axes):
    for img, ax in zip(sample[::int(len(sample)/cols)], ax_row):
        ax.imshow(img.reshape((28,28)), cmap='Greys_r')
        ax.xaxis.set_visible(False)
        ax.yaxis.set_visible(False)

# %% [markdown]
# ### 19.6.4 생성기로 새로운 영상 만들기

# %%
saver = tf.train.Saver(var_list=g_vars)
with tf.Session() as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    sample_z = np.random.uniform(-1, 1, size=(16, z_size))
    gen_samples = sess.run(
                   generator(input_z, input_size, n_units=g_hidden_size, reuse=True, alpha=alpha),
                   feed_dict={input_z: sample_z})
_ = view_samples(0, [gen_samples])
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints\generator.ckpt
